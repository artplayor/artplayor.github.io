# %%
from pyecharts import options as opts
from pyecharts.charts import Grid, Line, Scatter

from pyecharts.faker import Faker

# %%
# 折线图
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis('A', Faker.values())
    .add_yaxis('B', Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title='折线图', pos_left='5%'),
        legend_opts=opts.LegendOpts(pos_left='20%')
    )
)
# line.render_notebook()

# 散点图
scatter = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis('C', Faker.values())
    .add_yaxis('D', Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title='散点图', pos_right='40%'),
        legend_opts=opts.LegendOpts(pos_right='20%')
    )
)

# 多图布局
grid = (
    Grid()
    .add(line, grid_opts=opts.GridOpts(pos_right="55%"))
    .add(scatter, grid_opts=opts.GridOpts(pos_left="55%"))

)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aa294fd670874209a0bb6c5cbe45b449" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aa294fd670874209a0bb6c5cbe45b449 = echarts.init(
#                     document.getElementById('aa294fd670874209a0bb6c5cbe45b449'), 'white', {renderer: 'canvas'});
#                 var option_aa294fd670874209a0bb6c5cbe45b449 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     132
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     114
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     72
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     99
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     61
#                 ],
#                 [
#                     "VIVO",
#                     28
#                 ],
#                 [
#                     "OPPO",
#                     110
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     30
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     28
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     95
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     32
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     64
#                 ],
#                 [
#                     "VIVO",
#                     94
#                 ],
#                 [
#                     "OPPO",
#                     54
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "scatter",
#             "name": "C",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     145
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     74
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     34
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     37
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     141
#                 ],
#                 [
#                     "VIVO",
#                     86
#                 ],
#                 [
#                     "OPPO",
#                     124
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "D",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     50
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     28
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     140
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     81
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     74
#                 ],
#                 [
#                     "VIVO",
#                     70
#                 ],
#                 [
#                     "OPPO",
#                     147
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         },
#         {
#             "data": [
#                 "C",
#                 "D"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },

# %%
pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.7.1
# appdirs              1.4.4
# argon2-cffi          23.1.0
# argon2-cffi-bindings 21.2.0
# attrs                23.1.0
# backcall             0.2.0
# beautifulsoup4       4.12.2
# black                23.3.0
# bleach               6.0.0
# certifi              2023.7.22
# cffi                 1.15.1
# click                8.1.7
# cn2an                0.5.21
# colorama             0.4.6
# comm                 0.1.4
# debugpy              1.6.7.post1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# exceptiongroup       1.1.3
# fastjsonschema       2.18.0
# h11                  0.14.0
# html5lib             1.1
# idna                 3.4
# importlib-metadata   6.7.0
# importlib-resources  5.12.0
# ipykernel            6.16.2
# ipython              7.34.0
# ipython-genutils     0.2.0
# ipywidgets           8.1.0
# jedi                 0.19.0
# jieba                0.42.1
# Jinja2               3.1.2
# joblib               1.3.2
# jsonschema           4.17.3
# jupyter              1.0.0
# jupyter_client       7.4.9
# jupyter-console      6.6.3
# jupyter_core         4.12.0
# jupyter-server       1.24.0
# jupyterlab-pygments  0.2.2
# jupyterlab-widgets   3.0.8
# lightgbm             4.0.0
# MarkupSafe           2.1.3
# matplotlib-inline    0.1.6
# mistune              3.0.1
# mkl-fft              1.3.1
# mkl-random           1.2.2
# mkl-service          2.4.0
# mypy-extensions      1.0.0
# nbclassic            1.0.0
# nbclient             0.7.4
# nbconvert            7.6.0
# nbformat             5.8.0
# nest-asyncio         1.5.7
# notebook             6.5.5
# notebook_shim        0.2.3
# numpy                1.21.5
# outcome              1.2.0
# packaging            23.1
# pandas               1.2.3
# pandocfilters        1.5.0
# parso                0.8.3
# pathspec             0.11.2
# pickleshare          0.7.5
# Pillow               9.5.0
# pip                  22.3.1
# pkgutil_resolve_name 1.3.10
# platformdirs         3.10.0
# prettytable          3.7.0
# proces               0.1.6
# prometheus-client    0.17.1
# prompt-toolkit       3.0.39
# psutil               5.9.5
# pycparser            2.21
# pyecharts            2.0.4
# pyecharts-snapshot   0.2.0
# pyee                 8.2.2
# Pygments             2.16.1
# pyppeteer            1.0.2
# pyrsistent           0.19.3
# PySocks              1.7.1
# python-dateutil      2.8.2
# pytz                 2022.7
# pywin32              306
# pywinpty             2.0.10
# pyzmq                25.1.1
# qtconsole            5.4.3
# QtPy                 2.3.1
# ruamel.yaml          0.17.32
# ruamel.yaml.clib     0.2.7
# scikit-learn         1.0.2
# scipy                1.7.3
# selenium             4.11.2
# Send2Trash           1.8.2
# setuptools           58.0.4
# simplejson           3.19.1
# six                  1.16.0
# snapshot-selenium    0.0.2
# sniffio              1.3.0
# sortedcontainers     2.4.0
# soupsieve            2.4.1
# terminado            0.17.1
# threadpoolctl        3.1.0
# tinycss2             1.2.1
# tomli                2.0.1
# tornado              6.2
# tqdm                 4.66.1
# traitlets            5.9.0
# trio                 0.22.2
# trio-websocket       0.10.3
# typed-ast            1.5.5
# typing_extensions    4.7.1
# urllib3              1.26.16
# wcwidth              0.2.6
# webencodings         0.5.1
# websocket-client     1.6.1
# websockets           10.4
# wheel                0.38.4
# widgetsnbextension   4.0.8
# wincertstore         0.2
# wsproto              1.2.0
# xgboost              1.6.2
# zipp                 3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy --user
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
