# %% [markdown]
# ## Faker

# %%
# Faker
from pyecharts.faker import Faker

# %%
# 随机产生同属性的7个名词
Faker.choose()
# Out:
# ['河马', '蟒蛇', '老虎', '大象', '兔子', '熊猫', '狮子']

# %%
Faker.values()  # 随机的7个数
# Out:
# [125, 116, 105, 73, 96, 141, 114]

# %%
Faker.cars  # 7个车名
# Out:
# ['宝马', '法拉利', '奔驰', '奥迪', '大众', '丰田', '特斯拉']

# %%
Faker.country  # 7个国家
# Out:
# ['China', 'Canada', 'Brazil', 'Russia', 'United States', 'Africa', 'Germany']

# %%
Faker.visual_color  # 颜色
# Out:
# ['#313695',
#  '#4575b4',
#  '#74add1',
#  '#abd9e9',
#  '#e0f3f8',
#  '#ffffbf',
#  '#fee090',
#  '#fdae61',
#  '#f46d43',
#  '#d73027',
#  '#a50026']

# %%
Faker.days_attrs
# Out:
# ['0天',
#  '1天',
#  '2天',
#  '3天',
#  '4天',
#  '5天',
#  '6天',
#  '7天',
#  '8天',
#  '9天',
#  '10天',
#  '11天',
#  '12天',
#  '13天',
#  '14天',
#  '15天',
#  '16天',
#  '17天',
#  '18天',
#  '19天',
#  '20天',
#  '21天',
#  '22天',
#  '23天',
#  '24天',
#  '25天',
#  '26天',
#  '27天',
#  '28天',
#  '29天']

# %%
Faker.days_values
Faker.clock  # 时钟的列表

Faker.animal
Faker.dogs
Faker.clothes
Faker.guangdong_city
# Out:
# ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市', '广州市', '惠州市']

# %%
Faker.week
# Out:
# ['周一', '周二', '周三', '周四', '周五', '周六', '周日']

# %%
Faker.week_en
# Out:
# ['Saturday', 'Friday', 'Thursday', 'Wednesday', 'Tuesday', 'Monday', 'Sunday']

# %% [markdown]
# ## 饼图

# %%
from pyecharts.charts import Pie
import pyecharts.options as opts

# %%
Faker.choose()
# Out:
# ['衬衫', '毛衣', '领带', '裤子', '风衣', '高跟鞋', '袜子']

# %%
Faker.values()
# Out:
# [34, 70, 96, 124, 96, 97, 30]

# %%
list( zip(Faker.choose(), Faker.values()) )
# Out:
# [('小米', 61),
#  ('三星', 39),
#  ('华为', 95),
#  ('苹果', 25),
#  ('魅族', 104),
#  ('VIVO', 140),
#  ('OPPO', 25)]

# %%
[list(x)  for x in zip(Faker.choose(), Faker.values())]
# Out:
# [['草莓', 33],
#  ['芒果', 132],
#  ['葡萄', 27],
#  ['雪梨', 93],
#  ['西瓜', 52],
#  ['柠檬', 63],
#  ['车厘子', 45]]

# %%
c = Pie()
c.add('', [list(x)  for x in zip(Faker.choose(), Faker.values())])
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="49a1316cd5914c99ac728746516562fa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_49a1316cd5914c99ac728746516562fa = echarts.init(
#                     document.getElementById('49a1316cd5914c99ac728746516562fa'), 'white', {renderer: 'canvas'});
#                 var option_49a1316cd5914c99ac728746516562fa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 112
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_49a1316cd5914c99ac728746516562fa.setOption(option_49a1316cd5914c99ac728746516562fa);
#         });
#     </script>

# %%
c = (
    Pie()
    .add('', [list(x)  for x in zip(Faker.choose(), Faker.values())])
    .set_colors(['red', 'blue', 'green', 'orange', 'yellow', 'pink', 'black'])
    .set_global_opts(
        title_opts=opts.TitleOpts(title='设置颜色'),
        legend_opts=opts.LegendOpts(type_='scroll', pos_left="80%", orient='vertical')
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="32fae089897b42be9a5d616674f6525e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_32fae089897b42be9a5d616674f6525e = echarts.init(
#                     document.getElementById('32fae089897b42be9a5d616674f6525e'), 'white', {renderer: 'canvas'});
#                 var option_32fae089897b42be9a5d616674f6525e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "red",
#         "blue",
#         "green",
#         "orange",
#         "yellow",
#         "pink",
#         "black"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 57
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}:{c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u8bbe\u7f6e\u989c\u8272",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_32fae089897b42be9a5d616674f6525e.setOption(option_32fae089897b42be9a5d616674f6525e);
#         });
#     </script>

# %% [markdown]
# ### Pie-设置颜色-调整图例位置

# %%
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        # 饼图的中心（圆心）坐标，数组的第一项是横坐标，第二项是纵坐标
        # 默认设置成百分比，设置成百分比时第一项是相对于容器宽度，第二项是相对于容器高度
        center=["35%", "50%"],
    )
    .set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])   # 设置颜色
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-设置颜色-调整图例位置"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="70%", orient="vertical"),  # 调整图例位置
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="804a55ab00404b4eacea6f49221c2c2e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_804a55ab00404b4eacea6f49221c2c2e = echarts.init(
#                     document.getElementById('804a55ab00404b4eacea6f49221c2c2e'), 'white', {renderer: 'canvas'});
#                 var option_804a55ab00404b4eacea6f49221c2c2e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "blue",
#         "green",
#         "yellow",
#         "red",
#         "pink",
#         "orange",
#         "purple"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "70%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272-\u8c03\u6574\u56fe\u4f8b\u4f4d\u7f6e",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_804a55ab00404b4eacea6f49221c2c2e.setOption(option_804a55ab00404b4eacea6f49221c2c2e);
#         });
#     </script>

# %%
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        # 饼图的中心（圆心）坐标，数组的第一项是横坐标，第二项是纵坐标
        # 默认设置成百分比，设置成百分比时第一项是相对于容器宽度，第二项是相对于容器高度
        radius=['50%', '70%'],
        center=["35%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-设置颜色-调整图例位置"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="70%", orient="vertical"),  # 调整图例位置
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3603d52aa11540c494898e5267ced133" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3603d52aa11540c494898e5267ced133 = echarts.init(
#                     document.getElementById('3603d52aa11540c494898e5267ced133'), 'white', {renderer: 'canvas'});
#                 var option_3603d52aa11540c494898e5267ced133 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 97
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 31
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "70%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "70%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272-\u8c03\u6574\u56fe\u4f8b\u4f4d\u7f6e",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_3603d52aa11540c494898e5267ced133.setOption(option_3603d52aa11540c494898e5267ced133);
#         });
#     </script>

# %%
x_data = ["深度学习", "数据分析", "Web开发", "爬虫", "图像处理"]
y_data = [688, 888, 560, 388, 480]
data_pair = [list(z) for z in zip(x_data, y_data)]
data_pair.sort(key=lambda x: x[1])

c = (
    # 宽  高  背景颜色
    Pie(init_opts=opts.InitOpts( bg_color="#2c343c"))
    .add(
        series_name="学习方向",    # 系列名称
        data_pair=data_pair,      # 系列数据项，格式为 [(key1, value1), (key2, value2)]
        rosetype="radius",        # radius：扇区圆心角展现数据的百分比，半径展现数据的大小
        radius=["55%","80%"],             # 饼图的半径
        center=["50%", "50%"],    # 饼图的中心（圆心）坐标，数组的第一项是横坐标，第二项是纵坐标
        label_opts=opts.LabelOpts(is_show=False, position="center"),   #  标签配置项
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Customized Pie",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"  # 'item': 数据项图形触发，主要在散点图，饼图等无类目轴的图表中使用
         ),
        label_opts=opts.LabelOpts(color="rgba(255, 255, 255, 0.3)"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="79717789f94a4cf2960bdc673a0cf10a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_79717789f94a4cf2960bdc673a0cf10a = echarts.init(
#                     document.getElementById('79717789f94a4cf2960bdc673a0cf10a'), 'white', {renderer: 'canvas'});
#                 var option_79717789f94a4cf2960bdc673a0cf10a = {
#     "backgroundColor": "#2c343c",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5b66\u4e60\u65b9\u5411",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u722c\u866b",
#                     "value": 388
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u5904\u7406",
#                     "value": 480
#                 },
#                 {
#                     "name": "Web\u5f00\u53d1",
#                     "value": 560
#                 },
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60",
#                     "value": 688
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 888
#                 }
#             ],
#             "radius": [
#                 "55%",
#                 "80%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "color": "rgba(255, 255, 255, 0.3)",
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u722c\u866b",
#                 "\u56fe\u50cf\u5904\u7406",
#                 "Web\u5f00\u53d1",
#                 "\u6df1\u5ea6\u5b66\u4e60",
#                 "\u6570\u636e\u5206\u6790"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Customized Pie",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "top": "20",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "color": "#fff"
#             }
#         }
#     ]
# };
#                 chart_79717789f94a4cf2960bdc673a0cf10a.setOption(option_79717789f94a4cf2960bdc673a0cf10a);
#         });
#     </script>

# %% [markdown]
# ### 玫瑰图

# %%
v = sorted(Faker.values())
k = Faker.fruits
pie = Pie(init_opts=opts.InitOpts(width='800px', height='600px', bg_color='white'))
pie.add(
    '', [list(z) for z in zip(k, v)],
    radius=['10%', '70%'], center=['50%', '50%'], rosetype="radius"
).set_series_opts(
    label_opts=opts.LabelOpts(formatter="{b}: {c}")
).set_global_opts(
    title_opts=opts.TitleOpts(title='水果的热量对比(kcal/100g)', pos_left='300', pos_top='20',
        title_textstyle_opts=opts.TextStyleOpts(color='black', font_size=16)),
    legend_opts=opts.LegendOpts(is_show=True)
).set_colors(
    ['rgb({r},0,{b})'.format(r=255-20*(len(v)-x+1), b=255-15*x) for x in range(len(v))]
).render()
# Out:
# 'f:\\MyWebStation\\myBlog\\artPlayer\\source\\pyecharts\\render.html'

# %%
[list(i) for i in zip(v, Faker.values())]
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="161265fd26c44206a8530832e347e7f9" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_161265fd26c44206a8530832e347e7f9 = echarts.init(
#                     document.getElementById('161265fd26c44206a8530832e347e7f9'), 'white', {renderer: 'canvas'});
#                 var option_161265fd26c44206a8530832e347e7f9 = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 59
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 96
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 143
#                 }
#             ],
#             "radius": [
#                 "10%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u6c34\u679c\u7684\u70ed\u91cf\u5bf9\u6bd4(kcal/100g)",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "300",
#             "top": "20",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "color": "black",
#                 "fontSize": 16
#             }
#         }
#     ]
# };
#                 chart_161265fd26c44206a8530832e347e7f9.setOption(option_161265fd26c44206a8530832e347e7f9);
#         });
#     </script>

# %%
c = (
    Pie()
    .add(
        '',
        [list(i) for i in zip(v, Faker.values())],
        radius=['30%', '75%'],
        center=['25%', '50%'],
        rosetype='radius',
        label_opts=opts.LabelOpts(is_show=False)  # 不显示标签
    )
    .add(
        '',
        [list(i) for i in zip(v, Faker.values())],
        radius=['20%', '55%'],
        center=['75%', '50%'],
        rosetype='area',
        label_opts=opts.LabelOpts(is_show=True)  # 显示标签
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='玫瑰图'))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9642b7b0cdbc4b8a82231ac591eb837c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9642b7b0cdbc4b8a82231ac591eb837c = echarts.init(
#                     document.getElementById('9642b7b0cdbc4b8a82231ac591eb837c'), 'white', {renderer: 'canvas'});
#                 var option_9642b7b0cdbc4b8a82231ac591eb837c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 96
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 109
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         },
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 48
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "55%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u73ab\u7470\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_9642b7b0cdbc4b8a82231ac591eb837c.setOption(option_9642b7b0cdbc4b8a82231ac591eb837c);
#         });
#     </script>
